# %%
import pandas as pd
import numpy as np

# %%
Data=pd.read_csv(r"C:\Users\smkon\Downloads\movie_data/movies.csv")
Data.head(265)
# Out:
#      movieId                                   title  \
# 0          1                        Toy Story (1995)
# 1          2                          Jumanji (1995)
# 2          3                 Grumpier Old Men (1995)
# 3          4                Waiting to Exhale (1995)
# 4          5      Father of the Bride Part II (1995)
# ..       ...                                     ...
# 260      300                        Quiz Show (1994)
# 261      301       Picture Bride (Bijo photo) (1994)
# 262      302  Queen Margot (Reine Margot, La) (1994)
# 263      303          Quick and the Dead, The (1995)
# 264      304                        Roommates (1995)
#
#                                           genres
# 0    Adventure|Animation|Children|Comedy|Fantasy
# 1                     Adventure|Children|Fantasy
# 2                                 Comedy|Romance
# 3                           Comedy|Drama|Romance
# 4                                         Comedy
# ...

# %%
Data.shape
# Out:
# (9742, 3)

# %%
Data["title"][600:640:]
# Out:
# 600                                  Stupids, The (1996)
# 601                                  Arrival, The (1996)
# 602    Dr. Strangelove or: How I Learned to Stop Worr...
# 603              Ashes of Time (Dung che sai duk) (1994)
# 604               Maya Lin: A Strong Clear Vision (1994)
# 605                                    Stalingrad (1993)
# 606                                  Phantom, The (1996)
# 607                                    Striptease (1996)
# 608                                         Heavy (1995)
# 609                                          Jack (1996)
# 610                            I Shot Andy Warhol (1996)
# 611                                   Touki Bouki (1973)
# 612                           Spirits of the Dead (1968)
# 613                                 Trainspotting (1996)
# 614                            'Til There Was You (1997)
# 615                 Independence Day (a.k.a. ID4) (1996)
# ...

# %%
Data[Data["genres"]=="Sci-Fi"]
# Out:
#       movieId                                              title  genres
# 1719     2311              2010: The Year We Make Contact (1984)  Sci-Fi
# 1902     2526                                      Meteor (1979)  Sci-Fi
# 2000     2661                    It Came from Outer Space (1953)  Sci-Fi
# 2003     2665                Earth vs. the Flying Saucers (1956)  Sci-Fi
# 2026     2698                                     Zone 39 (1997)  Sci-Fi
# 2507     3354                             Mission to Mars (2000)  Sci-Fi
# 3121     4198                     Battle Beyond the Stars (1980)  Sci-Fi
# 3522     4813                         When Worlds Collide (1951)  Sci-Fi
# 3600     4942                       Angry Red Planet, The (1959)  Sci-Fi
# 3893     5468                   20 Million Miles to Earth (1957)  Sci-Fi
# 4122     5919                                     Android (1982)  Sci-Fi
# 4314     6302                        Beginning of the End (1957)  Sci-Fi
# ...

# %%
Data[["movieId"]]== "The Dark Night"
# Out:
#       movieId
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# ...       ...
# 9737    False
# 9738    False
# 9739    False
# 9740    False
# 9741    False
#
# [9742 rows x 1 columns]

# %%
Data.head(540)
# Out:
#      movieId                                        title  \
# 0          1                             Toy Story (1995)
# 1          2                               Jumanji (1995)
# 2          3                      Grumpier Old Men (1995)
# 3          4                     Waiting to Exhale (1995)
# 4          5           Father of the Bride Part II (1995)
# ..       ...                                          ...
# 535      632  Land and Freedom (Tierra y libertad) (1995)
# 536      633                       Denise Calls Up (1995)
# 537      634                          Theodore Rex (1995)
# 538      635                       Family Thing, A (1996)
# 539      636                                 Frisk (1995)
#
#                                           genres
# 0    Adventure|Animation|Children|Comedy|Fantasy
# 1                     Adventure|Children|Fantasy
# 2                                 Comedy|Romance
# 3                           Comedy|Drama|Romance
# ...

# %%
Data=pd.read_csv(r"C:\Users\smkon\Downloads\movie_data/ratings.csv")
Data.head(10)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
# 5       1       70     3.0  964982400
# 6       1      101     5.0  964980868
# 7       1      110     4.0  964982176
# 8       1      151     5.0  964984041
# 9       1      157     5.0  964984100

# %%
Data.shape
# Out:
# (100836, 4)

# %%
Data.nunique()
# Out:
# userId         610
# movieId       9724
# rating          10
# timestamp    85043
# dtype: int64

# %%
Data[Data["movieId"] == 1999]
# Out:
#        userId  movieId  rating   timestamp
# 7546       51     1999     5.0  1230931346
# 16025     104     1999     0.5  1053336552
# 88470     571     1999     1.0   966900688
# 97697     606     1999     1.5  1178911148

# %%
Data[Data["movieId"] == 1999][::]
# Out:
#       movieId                     title  genres
# 1474     1999  Exorcist III, The (1990)  Horror

# %%
Data=pd.read_csv(r"C:\Users\smkon\Downloads\movie_data/tags.csv")
Data.head(10)
# Out:
#    userId  movieId                tag   timestamp
# 0       2    60756              funny  1445714994
# 1       2    60756    Highly quotable  1445714996
# 2       2    60756       will ferrell  1445714992
# 3       2    89774       Boxing story  1445715207
# 4       2    89774                MMA  1445715200
# 5       2    89774          Tom Hardy  1445715205
# 6       2   106782              drugs  1445715054
# 7       2   106782  Leonardo DiCaprio  1445715051
# 8       2   106782    Martin Scorsese  1445715056
# 9       7    48516       way too long  1169687325
